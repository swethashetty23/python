# %%
text="Edukron Data Science and Data Engineering Batch 2026"

# %%
print(text[0:7])
print(text[-52:-45])
# Out:
# Edukron
# Edukron

# %%
print(text[8:12])
print(text[-44:-40])
# Out:
# Data
# Data

# %%
print(text[13:20])
print(text[-39:-32])
# Out:
# Science
# Science

# %%
print(text[21:24])
print(text[-31:-28])
# Out:
# and
# and

# %%
print(text[25:41])
print(text[-27:-11])
# Out:
# Data Engineering
# Data Engineering

# %%
print(text[30:41])
print(text[-22:-11])
# Out:
# Engineering
# Engineering

# %%
print(text[42:47])
print(text[-10:-5])
# Out:
# Batch
# Batch

# %%
print(text[48:52])
print(text[-4:])
# Out:
# 2026
# 2026

# %%
print(text[13:29])
print(text[-39:-22])
# Out:
# Science and Data
# Science and Data

# %%
print(text[8:47])
print(text[-44:-5])
# Out:
# Data Science and Data Engineering Batch
# Data Science and Data Engineering Batch
