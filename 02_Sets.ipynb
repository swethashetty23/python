# %% [markdown]
# Sets

# %%
#print customers set

customers = {"Amit", "Priya", "Rahul", "Divya"}
print(customers)
# Out:
# {'Divya', 'Amit', 'Priya', 'Rahul'}

# %%
# Find the number of elements in the customers
print(len(customers))
# Out:
# 4

# %%
# check whether "Rahul" exists in the customers set
if"Rahul" in customers:
  print("rahul is in set")
else:
  print("Rahul is not in list")
# Out:
# rahul is in set

# %%
# check "meena" exists in the customers set
if "Meena" in customers:
  print("Meena is in set")
else:
  print("Meena is not in set")
# Out:
# Meena is not in set

# %%
# add "meena" to the customers set
customers = {"Amit", "Priya", "Rahul", "Divya"}
customers.add("Meena")
print(customers)
# Out:
# {'Divya', 'Priya', 'Rahul', 'Amit', 'Meena'}

# %%
# add "Mysore" to the cities set
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
cities.add("Mysore")
print(cities)
# Out:
# {'Mysore', 'Pune', 'Chennai', 'Bangalore', 'Hyderabad'}

# %%
# update the customers set with new_customers
customers ={"Amit", "Priya", "Rahul", "Divya"}
new_customers = {"Sekhar", "Kalyan", "Ravi"}
customers.update(new_customers)
print(customers)
# Out:
# {'Divya', 'Priya', 'Ravi', 'Rahul', 'Sekhar', 'Amit', 'Kalyan'}

# %%
# update the cities set with new_cities
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
new_cities = {"Delhi","Noida", "Mumbai"}
cities.update(new_cities)
print(cities)
# Out:
# {'Delhi', 'Bangalore', 'Mumbai', 'Chennai', 'Hyderabad', 'Noida', 'Pune'}

# %%
# remove "Rahul" from customers set
customers ={"Amit", "Priya", "Rahul", "Divya"}
customers.remove("Rahul")
print(customers)
# Out:
# {'Divya', 'Amit', 'Priya'}

# %%
# remove "Pune" from cities set
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
cities.remove("Pune")
print(cities)
# Out:
# {'Bangalore', 'Hyderabad', 'Chennai'}

# %%
# Discard "Anita" from the customers set.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers.discard("Anitha")
print(customers)
# Out:
# {'Sneha', 'Vikram', 'Rahul', 'Kiran', 'Anita'}

# %%
# Discard "Delhi" from the cities set.
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
cities.discard("Delhi")
print(cities)
# Out:
# {'Bangalore', 'Hyderabad', 'Pune', 'Chennai'}

# %%
# Discard "Kolkata" from the cities set.
cities = {"Bangalore", "Hyderabad", "Chennai", "Kolkata", "Pune"}
cities.discard("kolkata")
print(cities)
# Out:
# {'Bangalore', 'Kolkata', 'Chennai', 'Hyderabad', 'Pune'}

# %%
# Remove a random element from the transaction_ids set using pop()
transaction_ids = {101, 102, 103, 104, 105}
transaction_ids.pop()
print(transaction_ids)
# Out:
# {102, 103, 104, 105}

# %%
# Remove another random element from the account_types set.
account_types = {"Savings", "Current", "Loan"}
account_types.pop()
print(account_types)
# Out:
# {'Current', 'Loan'}

# %%
# remove all elements from balances set.
balances = {85000, 120000, 45000, 95000, 275000}
balances.clear()
print(balances)
# Out:
# set()

# %%
#Create a copy of the customers set.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers1 = customers.copy()
customers1.pop()
print(customers)
print(customers1)
# Out:
# {'Sneha', 'Vikram', 'Rahul', 'Kiran', 'Anita'}
# {'Vikram', 'Rahul', 'Kiran', 'Anita'}

# %%
# find the union of customers and new_customers
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}

new_customers = {"Amit", "Priya", "Rahul", "Divya"}
customers.union(new_customers)
# Out:
# {'Amit', 'Anita', 'Divya', 'Kiran', 'Priya', 'Rahul', 'Sneha', 'Vikram'}

# %%
#Find the common customers between customers and new_customers.

customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}

new_customers = {"Amit", "Priya", "Rahul", "Divya"}
customers.intersection(new_customers)
# Out:
# {'Rahul'}

# %%
#Find customers who have both Savings and Loan accounts.
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
savings_customers = {"Rahul", "Sneha", "Priya", "Nikhil"}
customers.intersection(new_customers)
# Out:
# {'Rahul'}

# %%
#Find customers present only in customers but not in new_customers.

customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
customers.difference_update(new_customers)
customers
# Out:
# {'Anita', 'Kiran', 'Sneha', 'Vikram'}

# %%
#Find customers who have only Savings accounts
loan_customers= {"Rahul", "Kiran", "Asha", "Ramesh"}
savings_customers = {"Rahul", "Sneha", "Priya", "Nikhil"}
loan_customers.difference(savings_customers)
savings_customers
# Out:
# {'Nikhil', 'Priya', 'Rahul', 'Sneha'}

# %%
#Find customers that are present in either customers or new_customers but not both.

customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
customers.symmetric_difference(new_customers)
# Out:
# {'Amit', 'Anita', 'Divya', 'Kiran', 'Priya', 'Sneha', 'Vikram'}

# %%
# Check whether {"Rahul", "Kiran"} is a subset of loan_customers
loan_customers= {"Rahul", "Kiran", "Asha", "Ramesh"}
{"Rahul", "Kiran"}.issubset(loan_customers)
# Out:
# True

# %%
# Check whether customers is a superset of {"Rahul", "Anita"}
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
{"Rahul", "Anita"}.issuperset(customers)
# Out:
# False

# %%
#Check whether loan_customers and new_cities are disjoint.

loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
new_cities = {"Mumbai", "Bangalore", "Delhi"}
loan_customers.isdisjoint(new_cities)
# Out:
# True
